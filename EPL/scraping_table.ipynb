# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://fbref.com/en/comps/9/2024-2025/2024-2025-Premier-League-Stats"
    
# Add headers to mimic a browser request
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'
    }

response = requests.get(url, headers=headers)
response.raise_for_status()
print(response)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       4 headers = {
#       5         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
#       6         'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'
#       7     }
#       9 response = requests.get(url, headers=headers)
# ---> 10 response.raise_for_status()
#      11 print(response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")

results_table = soup.find('table', {'id': 'results2025-202691_overall'})
df = pd.read_html(str(results_table))[0]


columns_to_drop = ['Attendance', 'Notes', 'Top Team Scorer', 'Attendance', 'Goalkeeper', 'W', 'L', 'D', 'GF', 'GA', 'GD', 'MP']
df.drop(columns=columns_to_drop, inplace=True)

df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13284\654516193.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(results_table))[0]
#     Rk            Squad  Pts  Pts/MP    xG   xGA   xGD  xGD/90
# 0    1  Manchester City   93    2.45  88.7  24.6  64.0    1.68
# 1    2        Liverpool   92    2.42  88.7  33.8  54.9    1.45
# 2    3          Chelsea   74    1.95  63.4  33.2  30.1    0.79
# 3    4        Tottenham   71    1.87  61.2  39.3  21.9    0.58
# 4    5          Arsenal   69    1.82  60.5  45.7  14.9    0.39
# 5    6   Manchester Utd   58    1.53  55.8  53.0   2.8    0.07
# 6    7         West Ham   56    1.47  51.4  53.5  -2.1   -0.06
# 7    8   Leicester City   52    1.37  47.8  59.3 -11.5   -0.30
# 8    9         Brighton   51    1.34  46.2  42.9   3.3    0.09
# 9   10           Wolves   51    1.34  37.5  56.9 -19.4   -0.51
# ...

# %%
df.to_csv('pl22-table.csv', index=False)
